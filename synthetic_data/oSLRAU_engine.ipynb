# %% [markdown]
# <h1> Engine Dataset</h1>

# %%
from engine_dataset import generate_engine_dataset, generate_engine_datasets

from oSLRAU_run import get_data
from spn.structure.leaves.parametric.Parametric import Gaussian, Bernoulli, Categorical,  In_Latent, Multivariate_Gaussian
from spn.structure.Base import Context
from spn.algorithms.LearningWrappers import learn_parametric
from spn.io.Graphics import plot_spn
import numpy as np
from spn.algorithms.Inference import log_likelihood
from sklearn.model_selection import train_test_split
from spn.algorithms.oSLRAU import oSLRAU, oSLRAUParams
from spn.algorithms.RSPN import RSPN
from spn.algorithms.TransformStructure import Prune ,Prune_oSLRAU

from hmmlearn import hmm
from spn.algorithms.Inference import log_likelihood

# %%
a = Gaussian()
isinstance(a, Multivariate_Gaussian)
# Out:
# False

# %% [markdown]
# <h1> oSLRAU training funcs</h1>

# %%
def train_rspn_engine(train_data, test_data, epoch, rspn=None, os_args=None):

    if len(train_data.shape) == 3: train_data = np.squeeze(train_data)
    if len(test_data.shape) == 3: test_data = np.squeeze(test_data)

    if rspn is None:
    
        rspn = RSPN(num_variables=os_args["num_variables"], num_latent_variables=os_args["num_latent_variables"], num_latent_values=os_args["num_latent_values"])
        first_mini_batch = train_data[0:os_args["mini_batch_size"]]
        n = first_mini_batch.shape[1]

        print(f"n: {n}") # = num_time_steps_mix * n_dim
        
        context = [Gaussian, Gaussian, Categorical]*(int(n/3)) # Bernoulli Categorical
        ds_context = Context(parametric_types=context).add_domains(first_mini_batch[:, :os_args["num_variables"]])
        spn, initial_template_spn, top_spn = rspn.build_initial_template(first_mini_batch, ds_context, os_args["len_sequence_varies"])

    
    no_of_minibatches = int(train_data.shape[0] / os_args["mini_batch_size"])

    print(f"no of minibatches: {no_of_minibatches}")

    
    for i in range(1, no_of_minibatches):
        mini_batch = train_data[i * os_args["mini_batch_size"]: (i+1) * os_args["mini_batch_size"]]
    
        update_template = False
        
        # if (i % os_args["update_after_no_min_batches"] == 0) and (i!=0) :
        #if i % os_args["update_after_no_min_batches"] == 0 and i<=60 and epoch == 0:
        if i == 10:
            print(i)
            update_template = True
    
        template_spn = rspn.learn_rspn(mini_batch, update_template, os_args["os_params"], os_args["unroll"],
                                        os_args["full_update"], os_args["update_leaves"],
                                        os_args["len_sequence_varies"])
           
            
    test_ll = np.sum(rspn.log_likelihood(test_data, os_args["unroll"], os_args["len_sequence_varies"]))


    return test_ll, rspn, template_spn

# %%
def final_ll_engine(data, num_epochs=1, do_plot_spn=True, os_args=None, split_data=True):
    ll = -np.inf
    rspn=None
    if split_data:
        train_data, val_data= train_test_split(data, test_size=0.1, random_state=42)
    
    else:
        train_data, val_data = data, data
    for epoch in range(num_epochs):
        print(train_data.shape)
        
        
        epoch_ll, rspn, template_spn = train_rspn_engine(train_data, val_data, epoch, rspn, os_args)        
        print(f"epoch_ll: {epoch_ll}")
        
        ll = epoch_ll

    
    print(f" \n\n\n final ll: {ll}\n\n\n")

    if do_plot_spn:
        plot_spn(template_spn, 'rspn_final_template.pdf')
    
    return rspn

# %%
train_ds_raw, test_ds_raw = generate_engine_datasets(seeds=range(42, 43), development_samples=1000, test_samples=1000)

# %%
def osLRAU_pipeline(ds):
    assert len(ds) == 1
    if len(ds) == 1:
        ds = ds[0]
    
    ds_raw_disc = np.array(ds.observations_raw_discrete)
    ds_raw_cont = np.array(ds.observations_raw_continuous)
    ds_raw_input = np.array(ds.inputs_raw)

    first_dim, second_dim = ds_raw_disc.shape[:2]

    ds_comb = []

    for i in range(first_dim):
        curr_ds_comb = []
        for j in range(second_dim):
            curr_ds_comb_j = [*ds_raw_cont[i, j,:], ds_raw_input[i, j]]
            # curr_ds_comb_j = [ds_raw_cont[i, j,0], ds_raw_input[i, j]]
            curr_ds_comb.append(curr_ds_comb_j)
    
        ds_comb.append(curr_ds_comb)


    ds_comb = np.array(ds_comb)
    ds_comb = ds_comb.reshape(ds_comb.shape[0], -1)

    return ds_comb

train_ds = osLRAU_pipeline(train_ds_raw)
test_ds = osLRAU_pipeline(test_ds_raw)

assert len(train_ds.shape) == 2



n_states = 2
n_dim = 3

num_time_steps = 12

oSLRAU_params = oSLRAUParams(mergebatch_threshold=128, corrthresh=0.1, mvmaxscope=1, equalweight=True, currVals=True)

os_args = {
    "num_variables": num_time_steps * n_dim,
    "num_latent_variables" : 3,
    "num_latent_values" : 4,
    "unroll" : "backward",
    "full_update" : False,
    "update_leaves" : True,
    "len_sequence_varies" : False,
    "mini_batch_size" : 5,
    "update_after_no_min_batches" : 20,
    "os_params": oSLRAU_params
    }

rspn_engine = final_ll_engine(train_ds, num_epochs=3, do_plot_spn=False, os_args=os_args, split_data=False)
# Out:
# (1000, 36)
# n: 36
# ==>> data.shape: (5, 36)
# len(self.meta_types): 36
# self.meta_types.values(): dict_values([<MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>, <MetaType.REAL: 1>, <MetaType.REAL: 1>, <MetaType.DISCRETE: 3>])
# len(self.meta_types.values()): 36
# data[:, col]: [74.47765188 57.535537   54.65603964 50.77333836 54.86426868]
# ==>> domain_values: [50.77333836486729, 74.47765188288128]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [50.77333836486729, 74.47765188288128]
# len(self.meta_types.values()): 36
# data[:, col]: [ 76.53556304  97.34867747 104.63211002  47.06468112  52.8770515 ]
# ==>> domain_values: [47.06468112285236, 104.63211001824615]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [47.06468112285236, 104.63211001824615]
# len(self.meta_types.values()): 36
# data[:, col]: [1. 1. 1. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [71.78799073 49.07542525 60.04245765 49.46188309 40.04781038]
# ==>> domain_values: [40.04781038411719, 71.78799073103629]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [40.04781038411719, 71.78799073103629]
# len(self.meta_types.values()): 36
# data[:, col]: [ 76.03544546  48.0441805  100.56034564  46.68429205  50.39418276]
# ==>> domain_values: [46.684292050796955, 100.56034564398433]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [46.684292050796955, 100.56034564398433]
# len(self.meta_types.values()): 36
# data[:, col]: [1. 0. 1. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [62.59020468 55.10735189 48.55382746 47.07824142 51.84658133]
# ==>> domain_values: [47.07824142363661, 62.590204680634514]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [47.07824142363661, 62.590204680634514]
# len(self.meta_types.values()): 36
# data[:, col]: [97.25905537 52.21042683 50.61642243 48.09925994 50.68155841]
# ==>> domain_values: [48.099259943748024, 97.25905536729236]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [48.099259943748024, 97.25905536729236]
# len(self.meta_types.values()): 36
# data[:, col]: [1. 0. 0. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [57.03391986 42.11890314 59.39483895 50.04673876 49.27602893]
# ==>> domain_values: [42.11890314280326, 59.394838949278665]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [42.11890314280326, 59.394838949278665]
# len(self.meta_types.values()): 36
# data[:, col]: [97.09285218 72.4905751  97.41264373 47.52228091 50.06715681]
# ==>> domain_values: [47.52228090914835, 97.41264373075433]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [47.52228090914835, 97.41264373075433]
# len(self.meta_types.values()): 36
# data[:, col]: [1. 0. 1. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [39.6455863  54.04664091 51.14373235 70.69960459 62.5503249 ]
# ==>> domain_values: [39.645586297935964, 70.69960459226215]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [39.645586297935964, 70.69960459226215]
# len(self.meta_types.values()): 36
# data[:, col]: [70.91084808 57.09483339 53.43063203 85.07917155 73.13029321]
# ==>> domain_values: [53.430632033934984, 85.07917155060424]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [53.430632033934984, 85.07917155060424]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 1. 1.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [39.80672517 51.73688189 44.8197262  47.66825462 50.23692859]
# ==>> domain_values: [39.806725168457405, 51.736881893620414]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [39.806725168457405, 51.736881893620414]
# len(self.meta_types.values()): 36
# data[:, col]: [72.0384942  50.12792422 52.49787059 52.60719779 53.10437996]
# ==>> domain_values: [50.12792422340706, 72.03849420077358]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [50.12792422340706, 72.03849420077358]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 0. 0.]
# ==>> domain_values: [0.0, 0.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [47.79760023 40.79451872 55.70240256 48.39978185 48.86337576]
# ==>> domain_values: [40.7945187205321, 55.702402563747874]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [40.7945187205321, 55.702402563747874]
# len(self.meta_types.values()): 36
# data[:, col]: [ 54.87223987  50.24824732 103.1533665   54.57541432  52.55335384]
# ==>> domain_values: [50.24824731888818, 103.15336650400262]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [50.24824731888818, 103.15336650400262]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 1. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [38.50107432 59.23297714 48.40543024 47.48358301 45.30635721]
# ==>> domain_values: [38.50107431891205, 59.232977138134196]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [38.50107431891205, 59.232977138134196]
# len(self.meta_types.values()): 36
# data[:, col]: [73.83904744 53.54660664 46.51529228 50.84954956 45.1153411 ]
# ==>> domain_values: [45.11534110123521, 73.83904744316645]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [45.11534110123521, 73.83904744316645]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 0. 0.]
# ==>> domain_values: [0.0, 0.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [47.40198732 44.34770249 49.11088716 41.81136633 36.65495475]
# ==>> domain_values: [36.654954748456994, 49.110887162690446]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [36.654954748456994, 49.110887162690446]
# len(self.meta_types.values()): 36
# data[:, col]: [60.62025614 48.05366937 58.52165097 71.02511322 70.52965684]
# ==>> domain_values: [48.05366936513936, 71.02511322472998]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [48.05366936513936, 71.02511322472998]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 0. 0.]
# ==>> domain_values: [0.0, 0.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [47.33146178 45.02626971 47.80435546 74.2823351  40.46426628]
# ==>> domain_values: [40.46426627674906, 74.28233510370875]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [40.46426627674906, 74.28233510370875]
# len(self.meta_types.values()): 36
# data[:, col]: [45.6362383  47.32114374 49.89658645 72.33271631 69.23143013]
# ==>> domain_values: [45.63623829831177, 72.33271630675273]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [45.63623829831177, 72.33271630675273]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 1. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [46.4261684  52.61678343 62.19692694 46.58134056 48.69149323]
# ==>> domain_values: [46.42616839857741, 62.19692694004952]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [46.42616839857741, 62.19692694004952]
# len(self.meta_types.values()): 36
# data[:, col]: [47.17664926 50.50836357 97.45540785 43.15937645 47.60432376]
# ==>> domain_values: [43.15937645062006, 97.45540785309434]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [43.15937645062006, 97.45540785309434]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 1. 0. 0.]
# ==>> domain_values: [0.0, 1.0]
# feature_meta_type: MetaType.DISCRETE
# len(self.meta_types.values()): 36
# data[:, col]: [47.80331903 54.89978542 45.07972317 55.56639674 47.06740113]
# ==>> domain_values: [45.079723167094556, 55.56639674209227]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [45.079723167094556, 55.56639674209227]
# len(self.meta_types.values()): 36
# data[:, col]: [47.78989206 48.76913937 52.58489513 47.26302523 43.79932641]
# ==>> domain_values: [43.79932640873286, 52.58489512657816]
# feature_meta_type: MetaType.REAL
# ==>> domain_values: [43.79932640873286, 52.58489512657816]
# len(self.meta_types.values()): 36
# data[:, col]: [0. 0. 0. 0. 0.]
# ==>> domain_values: [0.0, 0.0]
# feature_meta_type: MetaType.DISCRETE
# Building initial spn
# Building initial template spn
# [[ 74.47765188  76.53556304   1.          71.78799073  76.03544546
#     1.          62.59020468  97.25905537   1.          57.03391986
#    97.09285218   1.          39.6455863   70.91084808   0.
#    39.80672517  72.0384942    0.          47.79760023  54.87223987
#     0.          38.50107432  73.83904744   0.          47.40198732
#    60.62025614   0.          47.33146178  45.6362383    0.
#    46.4261684   47.17664926   0.          47.80331903  47.78989206
#     0.        ]
#  [ 57.535537    97.34867747   1.          49.07542525  48.0441805
#     0.          55.10735189  52.21042683   0.          42.11890314
#    72.4905751    0.          54.04664091  57.09483339   0.
#    51.73688189  50.12792422   0.          40.79451872  50.24824732
#     0.          59.23297714  53.54660664   0.          44.34770249
#    48.05366937   0.          45.02626971  47.32114374   0.
#    52.61678343  50.50836357   0.          54.89978542  48.76913937
#     0.        ]
#  [ 54.65603964 104.63211002   1.          60.04245765 100.56034564
#     1.          48.55382746  50.61642243   0.          59.39483895
#    97.41264373   1.          51.14373235  53.43063203   0.
#    44.8197262   52.49787059   0.          55.70240256 103.1533665
#     1.          48.40543024  46.51529228   0.          49.11088716
#    58.52165097   0.          47.80435546  49.89658645   0.
#    62.19692694  97.45540785   1.          45.07972317  52.58489513
#     0.        ]
#  [ 50.77333836  47.06468112   0.          49.46188309  46.68429205
#     0.          47.07824142  48.09925994   0.          50.04673876
#    47.52228091   0.          70.69960459  85.07917155   1.
#    47.66825462  52.60719779   0.          48.39978185  54.57541432
#     0.          47.48358301  50.84954956   0.          41.81136633
#    71.02511322   0.          74.2823351   72.33271631   1.
#    46.58134056  43.15937645   0.          55.56639674  47.26302523
#     0.        ]
#  [ 54.86426868  52.8770515    0.          40.04781038  50.39418276
#     0.          51.84658133  50.68155841   0.          49.27602893
#    50.06715681   0.          62.5503249   73.13029321   1.
#    50.23692859  53.10437996   0.          48.86337576  52.55335384
#     0.          45.30635721  45.1153411    0.          36.65495475
#    70.52965684   0.          40.46426628  69.23143013   0.
#    48.69149323  47.60432376   0.          47.06740113  43.79932641
#     0.        ]]
# Building top spn
# no of minibatches: 200
# 20
# Updating template spn
# 40
# Updating template spn
# ==>> type(ci): <class 'spn.structure.leaves.parametric.Parametric.Categorical'>
# ==>> type(cj): <class 'spn.structure.leaves.parametric.Parametric.Gaussian'>
# 60
# Updating template spn
# ==>> type(ci): <class 'spn.structure.leaves.parametric.Parametric.Gaussian'>
# ==>> type(cj): <class 'spn.structure.leaves.parametric.Parametric.Categorical'>
# 80
# Updating template spn
# ==>> type(ci): <class 'spn.structure.leaves.parametric.Parametric.Gaussian'>
# ==>> type(cj): <class 'spn.structure.leaves.parametric.Parametric.Categorical'>
# ==>> type(ci): <class 'spn.structure.leaves.parametric.Parametric.Gaussian'>
# ==>> type(cj): <class 'spn.structure.leaves.parametric.Parametric.Gaussian'>
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/policy-venv_new/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1983: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/policy-venv_new/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1983: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=40'>41</a> oSLRAU_params = oSLRAUParams(mergebatch_threshold=128, corrthresh=0.1, mvmaxscope=1, equalweight=True, currVals=True)
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=42'>43</a> os_args = {
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=43'>44</a>     "num_variables": num_time_steps * n_dim,
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=44'>45</a>     "num_latent_variables" : 3,
#    (...)
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=52'>53</a>     "os_params": oSLRAU_params
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=53'>54</a>     }
# ---> <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=55'>56</a> rspn_engine = final_ll_engine(train_ds, num_epochs=3, do_plot_spn=False, os_args=os_args, split_data=False)
#
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> for epoch in range(num_epochs):
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     print(train_data.shape)
# ---> <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>     epoch_ll, rspn, template_spn = train_rspn_engine(train_data, val_data, epoch, rspn, os_args)
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>     print(f"epoch_ll: {epoch_ll}")
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a>     ll = epoch_ll
#
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=31'>32</a>         print(i)
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a>         update_template = True
# ---> <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a>     template_spn = rspn.learn_rspn(mini_batch, update_template, os_args["os_params"], os_args["unroll"],
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a>                                     os_args["full_update"], os_args["update_leaves"],
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>                                     os_args["len_sequence_varies"])
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=39'>40</a> test_ll = np.sum(rspn.log_likelihood(test_data, os_args["unroll"], os_args["len_sequence_varies"]))
#      <a href='vscode-notebook-cell:/Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work%20%28one%20drive%29/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/oSLRAU_and_RSPN/oSLRAU_engine_V2.ipynb#X10sZmlsZQ%3D%3D?line=42'>43</a> return test_ll, rspn, template_spn
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/RSPN.py:95, in RSPN.learn_rspn(self, mini_batch, update_template, oSLRAU_params, unroll, full_update, update_leaves, len_sequence_varies)
#      91     assert mini_batch.shape[
#      92                1] == self.num_variables * self.len_sequence, "data columns not equal to number of variables time length of sequence"
#      93     # print("Evaluating rspn and collecting nodes to update")
# ---> 95     nodes_to_update = self.evaluate_rspn(mini_batch, oSLRAU_params, unroll, full_update,
#      96                                          update_leaves)
#      98 if update_template:
#      99     print("Updating template spn")
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/RSPN.py:244, in RSPN.evaluate_rspn(self, data, oSLRAU_params, unroll, full_update, update_leaves)
#     241 for index in in_latent_index:
#     242     nodes[index].log_inference_value = 0
# --> 244 unrolled_network_lls_per_node = self.evaluate_rspn_bottom_up(data, unroll)
#     246 top_spn_lls_per_node = self.evaluate_top_spn_bottom_up(data, unrolled_network_lls_per_node)
#     247 self.evaluate_top_spn_top_down(data, top_spn_lls_per_node, oSLRAU_params)
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/RSPN.py:273, in RSPN.evaluate_rspn_bottom_up(self, data, unroll)
#     269     data_i = data[:, (i * self.num_variables): (i * self.num_variables) + (self.num_variables)]
#     271 assert data_i.shape[1] == self.num_variables
# --> 273 log_likelihood(self.template_spn, data_i, lls_matrix=lls_per_node)
#     274 unrolled_network_lls_per_node.append(lls_per_node)
#     276 for index in in_latent_index:
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/Inference.py:149, in log_likelihood(node, data, dtype, node_log_likelihood, lls_matrix, debug)
#     146 def log_likelihood(
#     147     node, data, dtype=np.float64, node_log_likelihood=_node_log_likelihood, lls_matrix=None, debug=False
#     148 ):
# --> 149     return likelihood(node, data, dtype=dtype, node_likelihood=node_log_likelihood, lls_matrix=lls_matrix, debug=debug)
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/Inference.py:137, in likelihood(node, data, dtype, node_likelihood, lls_matrix, debug)
#     133         return ll
#     135     node_likelihood = {k: exec_funct for k in node_likelihood.keys()}
# --> 137 result = eval_spn_bottom_up(node, node_likelihood, all_results=all_results, debug=debug, dtype=dtype, data=data)
#     139 if lls_matrix is not None:
#     140     for n, ll in all_results.items():
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/structure/Base.py:471, in eval_spn_bottom_up(node, eval_functions, all_results, debug, **args)
#     468         raise AssertionError("No lambda function associated with type: %s" % (n.__class__.__name__))
#     470 if n_is_leaf:
# --> 471     result = func(n, **args)
#     472 else:
#     473     len_children = len(n.children)
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/MIT/exchange_year/summer-UROP-knowledge-distillation/policy_stuff/policy-learn/SPFlow/src/spn/algorithms/Inference.py:109, in log_node_likelihood(node, *args, **kwargs)
#     107     nll = np.log(probs)
#     108 nll[np.isinf(nll)] = np.finfo(nll.dtype).min
# --> 109 assert not np.any(np.isnan(nll))
#     110 return nll
#
# AssertionError:

# %%
rspn_test_ll_engine = np.sum(rspn_engine.log_likelihood(test_ds, os_args["unroll"], os_args["len_sequence_varies"]))
rspn_test_ll_engine
# Out:
# Evaluating rspn bottom up
# -100086.54171639845
